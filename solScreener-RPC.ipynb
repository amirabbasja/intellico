# %%
import requests
import os
from utils import SOLANA_Handler
from pprint import pprint

ALCHEMY_API_KEY = "s9VcFEkkgF5LSo2yBtp0pO61DnIVQXjh"

solHandler = SOLANA_Handler(ALCHEMY_API_KEY)

blcNum = solHandler.get_latest_block()
info = solHandler.get_block_info(blcNum)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [9], in <cell line: 11>()
#       8 solHandler = SOLANA_Handler(ALCHEMY_API_KEY)
#      10 blcNum = solHandler.get_latest_block()
# ---> 11 info = solHandler.get_block_info(blcNum)
#
# File c:\Users\Spino.shop\Desktop\Trading\Apps\Python 28- Onchain screener\utils.py:497, in SOLANA_Handler.get_block_info(self, block_number)
#     487 def get_block_info(self, block_number: int):
#     488     """
#     489     Get detailed information about a specific block.
#     490
#    (...)
#     495         Optional[Dict[str, Any]]: Block information or None if request failed
#     496     """
# --> 497     data = self._make_request("getBlock", [block_number, {"encoding": "json", "maxSupportedTransactionVersion": 0}])
#     498     if data and "result" in data:
#     499         return data["result"]
#
# ...

# %%
len(info["transactions"])
# Out:
# 1571
